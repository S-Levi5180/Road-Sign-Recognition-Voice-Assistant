# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dataclusterlabs/indian-sign-board-image-dataset")

print("Path to dataset files:", path)
print("Hello World")
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 400M/400M [00:37<00:00, 11.2MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Bhagyashree\.cache\kagglehub\datasets\dataclusterlabs\indian-sign-board-image-dataset\versions\3
# Hello World

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "dataclusterlabs/indian-sign-board-image-dataset",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# C:\Users\Bhagyashree\AppData\Local\Temp\ipykernel_20908\1338542487.py:10: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 10
#       7 file_path = ""
#       9 # Load the latest version
# ---> 10 df = kagglehub.load_dataset(
#      11   KaggleDatasetAdapter.PANDAS,
#      12   "dataclusterlabs/indian-sign-board-image-dataset",
#      13   file_path,
#      14   # Provide any additional arguments like
#      15   # sql_query or pandas_kwargs. See the
#      16   # documenation for more information:
#      17   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
#      18 )
#      20 print("First 5 records:", df.head())
#
# ...

# %%
import pandas as pd
data=pd.read_csv(C:\Users\Bhagyashree\.cache\kagglehub\datasets\dataclusterlabs\indian-sign-board-image-dataset\versions\3)
